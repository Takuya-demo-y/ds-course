# %% [markdown]
# # Ch.1  データを「読む」
#
# 【講師用完全版】
#
# | 項目 | 内容 |
# |------|------|
# | 使うデータ | ワインデータ 178件・13特徴量・3品種 |
# | 演習時間 | 40分（問3まで完了で合格） |
# | ゴール | 集計・フィルタリングでビジネス上の問いに答えられる |
#
# 「どのコマンドを使うか」ではなく「何を知りたいか」を Copilot に伝えましょう。

# %% [markdown]
# ---
# ### 📌 講師メモ：時間配分と時間が押した場合の対応
#
# | 区分 | 内容 | 目安時間 |
# |------|------|---------|
# | 座学（concept_ch1） | データ分析の3ステップ・欠損値・集計・フィルタリング | 25分 |
# | 演習（準備〜問2） | ライブラリ読み込み・STEP1・問1・問2 | 30分 |
# | 演習（問3） | 考察・言語化（AI禁止） | 10分 |
# | 問4（発展） | フィルタリング | 余り次第 |
#
# **時間が押した場合：**
# - 問3（考察）を「後で記入」として先に進んでもよい
# - 問4（発展）は最初から「時間が余った人向け」と案内する
# - **問2まで完了していれば Ch.2 に進んで問題ない**

# %% [markdown]
# ---
# ## Copilot の使い方
#
# URL: https://copilot.microsoft.com
#
# Copilot への伝え方のコツ（5点セット）：
# ```
# 【知りたいこと】〇〇を調べたい / 〇〇を計算したい
# 【使うライブラリ】pandas
# 【データの形】df という DataFrame、178行×14列（数値13列 + 品種名列）
# 【環境】Python 3.8.6、JupyterLab
# 【困っていること】どう書けばよいかわからない
# ```
#
# 「df.head() を使って」のように方法を聞くのではなく、
# 「〇〇したい、どうすればよいか」と目的を伝えましょう。

# %% [markdown]
# ---
# ## 準備  ライブラリとデータを読み込む
#
# ⛔ 注意 最初にこのセルを実行してください。実行しないと以降が動きません。

# %%
import pandas as pd
from sklearn.datasets import load_wine

wine = load_wine()
df   = pd.DataFrame(wine.data, columns=wine.feature_names)
df["品種名"] = ["wine_" + str(t) for t in wine.target]
print(f"行数: {len(df)}  列数: {len(df.columns)}")

# %% [markdown]
# ---
# ## STEP 1  このデータ、何が入っているだろう？
#
# なぜ最初にデータを確認するのか
#
# データを初めて受け取ったとき、まず「何が入っているか」を確認します。
# 列名・件数・型・欠損の有無を把握してから分析を始めるのがプロの習慣です。
#
# ---
#
# STEP 0  データの「大きさ」を確認しましょう
#
# 何行・何列のデータかを確認してください。全体の規模を把握することが STEP 1 の出発点です。
#
# 💡 ヒント Copilot への相談例：
# 「pandas の DataFrame の行数と列数を同時に確認したい」
#
# ---
#
# Q1-1  データの「顔」を見てみましょう
#
# 先頭の数行を見て、どんなデータかを確認してください。
#
# 💡 ヒント Copilot への相談例：
# 「pandas の DataFrame の最初の数行を確認したい。どうすればよいか？」

# %%
# DataFrame の行数と列数（行×列）を確認する
df.shape

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# (178, 14)
# ```
#
# | 出力の読み方 | 意味 |
# |------------|------|
# | 178 | 行数（データ件数） |
# | 14 | 列数（特徴量13列 + 品種名1列） |
#
# 📌 ポイント：`df.shape` は「このデータの全体像」を1行で確認できる最初のコマンド。
# - `df.shape[0]` → 行数のみ
# - `df.shape[1]` → 列数のみ
#
# ✅ （模範解答）(178, 14) → 178件・14列のデータ。
#
# 📌 講師メモ：スライドに「178行×14列」とあることと照合して確認すると、受講生の理解が確認しやすい。

# %%
# 先頭5行を表示して、列名・数値の大きさ・品種名列を確認する
df.head()

# %% [markdown]
# ---
# Q1-1（追加）  末尾のデータも確認してみましょう
#
# 先頭だけでなく末尾も見ることで、データが途中で途切れていないか・異常な値がないかを確認できます。
#
# 💡 ヒント：「DataFrame の末尾の数行を表示する方法」を Copilot に聞いてみましょう。

# %%
# DataFrame の末尾3行を表示して、先頭との違いがないか確認する
df.tail(3)

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# `df.tail(3)` を実行すると末尾3行が表示されます。
#
# 📌 ポイント：先頭と末尾の値の範囲を比べて、極端な値がないか確認します。
# 末尾に NaN が集中している場合は欠損値が行全体に偏っている可能性があります。

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# `df.head()` を実行すると先頭5行の表が表示されます。
#
# | 確認するポイント | 見るべきこと |
# |----------------|------------|
# | 列名 | alcohol・malic_acid・proline など 13 項目 + 品種名 |
# | 数値の大きさ | alcohol は 11〜14 程度、proline は 278〜1680 と桁が違う |
# | 品種名列 | wine_0・wine_1・wine_2 の 3 種類 |
#
# 📌 ポイント 数値の桁が揃っていない列（proline など）は、機械学習では「スケーリング」が必要になることがある。
# Ch.1 では概念を掴むだけでよい。
#
# 📌 講師メモ: 受講生が「どんな列があるか」を目で確認できているかを問い返す。

# %% [markdown]
# ---
# Q1-2  データの全体像（件数・型・欠損）を調べてみましょう
#
# 何行・何列あるか、欠損値はあるか、各列のデータ型は何かを確認してください。
#
# 💡 ヒント Copilot への相談例：
# 「DataFrame の行数・列名・データ型・欠損値の件数をまとめて確認したい」

# %%
# 列名・データ型・欠損値の件数をまとめて表示する
df.info()

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
#  0   alcohol       178 non-null    float64
#  ...
#  13  品種名          178 non-null    object
# ```
#
# | 確認するポイント | 見るべきこと |
# |----------------|------------|
# | 欠損なし | 全列「178 non-null」→ 欠損値ゼロ |
# | 型 | 数値列は float64、品種名のみ object（文字列） |
#
# 📌 ポイント Non-Null Count が行数より少ない列があれば欠損値がある。
# このデータは欠損なし。欠損があった場合の対処は「補完 or 削除」の 2 択。
#
# 📌 講師メモ: 欠損値の概念（空欄があると集計・学習に影響する）を 1 分で補足する。

# %% [markdown]
# ---
# Q1-2（補足）  欠損値の件数を列ごとに数えてみましょう
#
# `df.info()` で大まかに確認しましたが、欠損値が何列に何件あるかを**数値で**確認する方法があります。
#
# 💡 ヒント Copilot への相談例：
# 「pandas で列ごとに欠損値（NaN）の件数を数えたい」
#
# 📌 このデータには欠損値はありません。でもこのコマンドは**どんなデータを渡されても必ず最初に実行する**習慣にしましょう。

# %%
# 列ごとの欠損値の件数を数えて、欠損がないか確認する
df.isnull().sum()

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# alcohol                         0
# malic_acid                      0
# ash                             0
# ...
# 品種名                           0
# dtype: int64
# ```
#
# | 確認するポイント | 見るべきこと |
# |----------------|------------|
# | すべて 0 | 欠損値ゼロ = どの列にも空欄なし |
# | 0 以外が出たら | その列に欠損がある → 対処が必要（削除 or 補完） |
#
# 📌 ポイント `df.info()` の Non-Null Count と結果は一致する。
# `isnull().sum()` は「欠損数を一目で数値で確認できる」ので、実務では必ずセットで実行する。
#
# 📌 講師メモ: Ch.4 で `shift()` を使うと最初の1行が NaN になり `dropna()` が必要になる。
# ここで「欠損 = 計算できない行」という感覚を掴んでおくと Ch.4 で理解がスムーズになる。

# %% [markdown]
# ---
# Q1-3  数値の「大きさの感覚」を掴みましょう
#
# 各列の平均・最大・最小・標準偏差などの統計量を確認してください。
#
# 💡 ヒント Copilot への相談例：
# 「DataFrame の全列について、平均・最大・最小・標準偏差をまとめて見たい」
#
# 実行したら、**std（標準偏差）の欄**を見て「ばらつきが一番大きい列」を探してみましょう。
# 📌 std（標準偏差）= 値のばらつきの大きさを示す数値。
#    例）全員が平均50点のテスト → std ≈ 0（みんな同じ点数）
#        得点が20点〜80点とバラバラ → std は大きい
#    std が大きい列ほど「品種によって値が違う＝分類に効く特徴量候補」と考えられます。
# → チェックポイントで答えを記入します。

# %%
# 全列の基本統計量（平均・標準偏差・最大・最小）を表示する
df.describe().round(2)

# %% [markdown]
# ---
# Q1-3（追加）  ばらつき（std）が大きい列をランキングで確認しましょう
#
# `describe()` の結果を全列並べると多すぎて見づらいです。
# std の値だけを取り出して大きい順に並べると「品種差が出やすい変数の候補」が一目でわかります。
#
# 💡 ヒント：「describe() の std 行だけを取り出して降順に並べる方法」を Copilot に聞いてみましょう。

# %%
# std（標準偏差）の値を全列分取り出して、ばらつきが大きい列を上位から確認する
df.describe().loc["std"].sort_values(ascending=False).head(5)

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# proline        314.9
# color_intensity   2.3
# magnesium        14.3
# malic_acid        1.1
# alcohol           0.8
# ```
#
# 📌 ポイント：`proline` が std 断トツ1位。値の範囲が 278〜1680 と広く、品種ごとに大きな差があります。
# → Ch.2 の箱ひげ図・散布図、Ch.3 の特徴量重要度で「proline が効く変数かどうか」を確認する伏線になります。
#
# ✅ （模範解答）proline・color_intensity・magnesium の std が大きい。特に proline は断然1位。

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# | 確認するポイント | 見るべきこと |
# |----------------|------------|
# | std（標準偏差）が大きい列 | proline（std ≈ 314）が最大 → ばらつきが大きい |
# | min と max の差が大きい列 | proline: 最小 278 〜 最大 1680 |
# | alcohol | 平均 ≈ 13.0、最小 11.0、最大 14.8 と比較的安定 |
#
# 📌 ポイント 標準偏差が大きい = 値のばらつきが大きい = 品種の違いを表す「決め手」になる可能性がある。
#
# 📌 講師メモ: 「Ch.2 でこの気づきを可視化します」と予告する。

# %% [markdown]
# ---
# ### STEP 1 チェックポイント（AI 禁止：考えて記入）
#
# Q：このデータには何種類のワインが入っていますか？
# ✅ （模範解答） 3種類（wine_0・wine_1・wine_2）。
#
# Q：欠損値はありましたか？（`isnull().sum()` の出力を確認）
# ✅ （模範解答） 欠損なし。全列が 0 と表示される。
#
# Q：ばらつき（std）が最も大きかった列はどれでしたか？（`df.describe()` の std 行を確認）
# ✅ （模範解答） `proline`（std ≈ 314）が最大。次いで `od280/od315_of_diluted_wines`（std ≈ 0.71）など。
#
# 📌 講師メモ: 「proline の std が大きいとはどういう意味か」を 1 分で補足する。
# → 問2 の集計で wine_0 の proline が他品種の 2倍以上あることとつながる。

# %% [markdown]
# ---
# ## 問1  品種ごとにデータが何件あるか調べる ★☆☆
#
# 実務でのイメージ：
# 「商品カテゴリ別の注文件数を確認する」「地域別のユーザー数を調べる」
# -- カテゴリごとの件数確認は、どんなデータ分析でも最初に行う基本操作です。
#
# ---
#
# Q1-a：このデータにどんな品種（カテゴリ）があるか確認しましょう
#
# 集計の前に「何種類のカテゴリがあるか」を確認します。
# 実務では、表記ゆれ（"wine_0" と "Wine_0" の混在など）の発見にも使えます。
#
# 💡 ヒント Copilot への相談例：
# 「pandas で列のユニークな値の一覧を取得したい」
#
# ---
#
# Q1-b：品種ごとに何件のデータが入っているか調べてみましょう
#
# 3種類の品種（wine_0・wine_1・wine_2）それぞれが何件あるかを確認してください。
#
# 💡 ヒント Copilot への相談例：
# 「pandas で特定の列のカテゴリごとの件数を数えたい」

# %%
# 品種名列にどんなカテゴリ（値）が存在するかを確認する
df["品種名"].unique()

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# array(['wine_0', 'wine_1', 'wine_2'], dtype=object)
# ```
#
# | 確認するポイント | 見るべきこと |
# |----------------|------------|
# | 種類数 | 3種類（wine_0・wine_1・wine_2） |
# | 表記ゆれ | 全て小文字・アンダーバー区切りで統一されている |
#
# 📌 ポイント：`unique()` は「どんな値があるか」、`value_counts()` は「それぞれ何件あるか」を確認する。
# 実務データでは、同じ商品が "Product_A" と "product_a" で混在することがよくある。まず `unique()` でカテゴリを確認する習慣をつけると気づきやすい。
#
# ✅ （模範解答）wine_0・wine_1・wine_2 の3種類。表記ゆれなし。
#
# 📌 講師メモ：「もし 'wine_00' という値が1件混じっていたら何が起きるか？」を問い返すと表記ゆれの問題の深刻さが伝わる。

# %%
# 品種ごとの件数を集計して、多い順に表示する
df["品種名"].value_counts()

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# wine_1    71
# wine_0    59
# wine_2    48
# ```
#
# | 確認するポイント | 見るべきこと |
# |----------------|------------|
# | 件数の偏り | wine_1（71件）が最多、wine_2（48件）が最少 |
# | 合計 | 59 + 71 + 48 = 178件 → STEP1 の行数と一致 |
#
# 📌 ポイント クラスに大きな偏りがある場合、機械学習の精度評価に注意が必要（不均衡データ）。
# 今回は最大 71 / 最小 48 ≈ 1.5倍の差なのでそこまで問題にならない。
#
# 📌 講師メモ: 「合計が178件と一致するか確認して」と問い返すと理解度がわかる。
#
# ✅ （模範解答）wine_1 が 71件で最多、wine_0 が 59件、wine_2 が 48件で最少。合計 178件。

# %% [markdown]
# ---
# Q1-c（追加）  クラスバランスを割合で確認しましょう
#
# 件数だけでなく「全体に占める割合」を見ると、クラスの偏りが一目でわかります。
#
# 📌 なぜ重要か：機械学習では、あるクラスが90%を占めていると「常に多数派を予測するだけで90%正解」という偽物の高精度が生まれます（不均衡データ問題）。Ch.3 の前にバランスを確認する習慣をつけましょう。
#
# 💡 ヒント Copilot への相談例：
# 「value_counts() の結果を割合（0〜1）で表示したい」

# %%
# 品種ごとの割合（クラスバランス）を確認する
df["品種名"].value_counts(normalize=True).round(3)

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# 品種名
# wine_1    0.399
# wine_0    0.331
# wine_2    0.270
# ```
#
# | 確認するポイント | 見るべきこと |
# |----------------|------------|
# | 割合の範囲 | 27〜40% で、最大と最小の差は約 13% |
# | 均衡かどうか | 極端な偏りはない（0.9 以上や 0.1 以下のクラスがないか確認） |
#
# 📌 ポイント：wine_1 が全体の40%、wine_2 が27%と若干多い/少ないが、機械学習で問題になるレベルではない。
# （極端な不均衡：例えば1クラスが95%を占める場合は精度指標に注意が必要）
#
# ✅ （模範解答）最多は wine_1（約40%）、最少は wine_2（約27%）。均衡データに近く、Ch.3 の学習には問題ない。
#
# 📌 講師メモ：「もし wine_0 が95%を占めていたら何が起きるか？」を問い返すと不均衡データ問題の概念が伝わりやすい。

# %% [markdown]
# ---
# ## 問2  品種ごとにアルコールとプロリンの平均を比べる ★★☆
#
# 実務でのイメージ：
# 「部署別の売上平均を比べる」「商品カテゴリ別の単価の違いを調べる」
# -- グループ別の集計は、差の発見と原因特定に使う基本技術です。
#
# ---
#
# Q2-1：品種ごとの「アルコール度数の平均」を調べてみましょう
#
# 3品種のアルコール度数（alcohol）の平均値を、品種別に比較してください。
#
# 💡 ヒント Copilot への相談例：
# 「pandas で列の値でグループに分けて、別の列の平均を計算したい」

# %%
# 品種ごとに alcohol の平均を集計して比較する
df.groupby("品種名")["alcohol"].mean().round(2)

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# 品種名
# wine_0    13.74
# wine_1    12.28
# wine_2    13.15
# ```
#
# 📌 ポイント wine_0（約 13.7）と wine_1（約 12.3）で 1.4 度の差がある。
# alcohol はワインの品種を区別する「有力な手がかり」かもしれない（Ch.3 で検証する）。
#
# 📌 講師メモ: 「Ch.2 でこれをグラフにします。どの品種が一番違いそうですか？」と問い返す。
#
# ✅ （模範解答）wine_0（13.74）が最も高く、wine_1（12.28）が最も低い。差は約 1.5 度。

# %% [markdown]
# ---
# Q2-2：今度は alcohol と proline の両方を同時に集計してみましょう
#
# 品種ごとに 2 列まとめて平均を出してください。
#
# 📌 なぜ proline？：Q1-3 の `describe()` で std（標準偏差）が最も大きかった列です。
# 「ばらつきが大きい = 品種ごとに差が出やすい」可能性が高いため、alcohol とセットで確認します。
#
# 💡 ヒント Copilot への相談例：
# 「pandas で複数の列を指定してグループ別に平均を出したい」

# %%
# 品種ごとに alcohol と proline の平均を一度にまとめて集計する
df.groupby("品種名")[["alcohol", "proline"]].mean().round(2)

# %% [markdown]
# ---
# Q2-3（追加）  平均だけでなく「最大・最小」も見てみましょう
#
# 平均（mean）だけでは「ばらつきの大きさ」「極端な値の有無」がわかりません。
# 最大・最小・中央値を同時に確認すると、品種の特徴がより鮮明になります。
#
# 📌 例えば wine_0 の proline の最小値は？wine_1 の最大値より低いですか？
#
# 💡 ヒント：「groupby と agg を組み合わせて複数の統計量を同時に計算する方法」を Copilot に聞いてみましょう。

# %%
# 品種ごとに alcohol と proline の平均・最大・最小を一度に計算して、品種間の差をより詳しく確認する
df.groupby("品種名")[["alcohol", "proline"]].agg(["mean", "max", "min"]).round(1)

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
#          alcohol              proline
#             mean   max   min     mean    max   min
# 品種名
# wine_0      13.7  14.8  11.5   1115.7   1680   625
# wine_1      12.3  14.2  11.0    519.5    985   278
# wine_2      13.2  14.8  11.6    629.9   1020   415
# ```
#
# 📌 ポイント：wine_0 の proline は最小値でも 625 あり、wine_1・wine_2 の平均より高い。
# 「平均で差がある」だけでなく「範囲が重なっていない」ことが確認できると、分類に使える変数かどうかがより明確になります。
#
# ✅ （模範解答）wine_0 の proline の最小値（625）は wine_1 の平均（519）より高く、ほぼ重なりがない。
# alcohol は最大・最小が重複しているため、単独では品種の区別が難しい。

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
#          alcohol  proline
# 品種名
# wine_0    13.74   1115.71
# wine_1    12.28    519.51
# wine_2    13.15    629.90
# ```
#
# 📌 ポイント proline の差が非常に大きい：wine_0（1116）は wine_1（520）の約 2倍。
# STEP1 で「proline は std が最大」と気づいた理由がここで分かる。
# EDA で気づいた数値の意味が、集計で裏付けられる -- これがデータ分析の流れ。
#
# 📌 講師メモ: 「なぜ proline の差が大きいと思う？」と問い返し、考察を促す。
#
# ✅ （模範解答）proline の差が最も顕著。wine_0 は wine_1 の約 2倍のプロリンを含む。
# 品種を区別する変数として proline が有力な候補。

# %% [markdown]
# ---
# ### 問2 チェックポイント（AI 禁止：考えて記入）
#
# Q：alcohol と proline のどちらが品種を区別しやすそうですか？その理由は？
# ✅ （模範解答）proline の方が品種間の差が大きい（wine_0 は wine_1 の約 2倍）ため、proline の方が品種の区別に有効な可能性が高い。

# %% [markdown]
# ---
# ## 問3  集計から「気づき」を言語化する ★★☆（AI 禁止）
#
# 実務でのイメージ：
# データ分析の最終成果物は「グラフ」ではなく「言葉（インサイト）」です。
# 「この変数が品種を分けている可能性がある」という仮説を言語化できることが、
# データサイエンティストとして最も重要なスキルです。
#
# ---
#
# Q3：問1・問2の結果から、どんな発見がありましたか？
#
# ⛔ 注意 このセルはコードではなく、文章で記入してください。AI は使わないこと。
#
# 発見・気づきを書いてください：
#
# 💡 書き方の例（どれかを参考にしてください）：
# ① 「〇〇の値は〇〇（品種）が最も大きく、〇〇（品種）の約○倍だった」
# ② 「〇〇と〇〇を組み合わせると、3品種がほぼ区別できそうだと気づいた」
# ③ 「std が最大だった proline が品種を分けるカギになりそうだと思った」
#
# >
#
# その発見は実務でどう使えそうですか？
#
# 💡 考え方のヒント：「品種」を「商品カテゴリ」や「顧客グループ」に置き換えてみましょう。
# 例）wine_0 は alcohol・proline が高い → 「高価格帯の商品群」として扱うと何が見えてくるか？
#
# >

# %% [markdown]
# ---
# ### 📌 講師メモ（問3 の模範解答）
#
# ✅ （模範解答）
# - wine_0 はアルコールが高く、プロリンが他品種の 2 倍以上 → 高品質・高価格帯ワインの特徴かもしれない
# - wine_1 はアルコールもプロリンも低い → 軽口で手頃なワインか？
# - この 2 変数だけで品種を区別できる可能性がある → Ch.3 の機械学習で検証する
#
# 実務への接続（具体的な模範例）：
# - 「品種 → 商品カテゴリ」「alcohol → 単価」「proline → 原価」と読み替えると？
#   → 「wine_0 カテゴリは単価・原価ともに高い = 高付加価値商品群」という仮説が立てられる
#   → このカテゴリへの仕入れ強化 or 価格戦略の見直しという次のアクションにつながる
#
# よくある受講生の詰まり方：
# - 「何を書けばいいかわからない」→「数値を見て、差が大きいものを指摘するだけでOK」と伝える
# - 「実務への接続が難しい」→ 上記の「〇〇 → ××に読み替えると」のフレームを口頭で補足する

# %% [markdown]
# ---
# ## 問4（発展）  条件でデータを絞り込む ★★★
#
# 📋 発展 時間が余った人だけ取り組んでください
#
# 実務でのイメージ：
# 「アルコール度数が高いワインだけを抽出して品種の内訳を確認する」
# ← 「売上が前月比 -20% 以下の商品だけ抽出して原因を調べる」と同じ操作です。
#
# ---
#
# Q：アルコール度数が高く、かつプロリンも多いワインだけを取り出してみましょう
#
# 「アルコール >= 13.5 かつ プロリン >= 700」の条件で絞り込み、品種の内訳を確認してください。
#
# 💡 なぜこの数値？：問2の集計結果で wine_0 の alcohol 平均が 13.74、proline 平均が 1115 と他の品種より大幅に高かったことを参考に、「wine_0 っぽい条件」を設定しています。
#
# 💡 ヒント Copilot への相談例：
# 「pandas で 2 つの条件を同時に満たす行だけを取り出したい（AND 条件）」

# %%
# AND 条件（アルコール高 かつ プロリン多）でデータを絞り込み、品種の内訳を確認する
premium = df[(df["alcohol"] >= 13.5) & (df["proline"] >= 700)]
print(f"絞り込み後: {len(premium)} 件")
premium["品種名"].value_counts()

# %% [markdown]
# ---
# ### 📊 出力結果の解説
#
# ```
# 絞り込み後: 51 件
# 品種名
# wine_0    51
# ```
#
# 📌 ポイント 「アルコール高 + プロリン多」の条件を満たすのは wine_0 のみ（51件全部）。
# この 2 変数の組み合わせで wine_0 を完全に識別できる可能性がある。
# 「条件で絞り込む = ビジネスルールで顧客・商品を分類する」と同じ発想。
#
# ✅ （模範解答）絞り込み後 51 件すべてが wine_0。
# この 2 変数の組み合わせは wine_0 の識別に非常に有効であることが分かる。

# %% [markdown]
# ---
# ## お疲れさまでした！
#
# | 操作 | 発見 | 次の Ch への接続 |
# |------|------|----------------|
# | 件数確認 | 3品種がおよそ均等（48〜71件） | -- |
# | グループ集計 | alcohol・proline で品種間に明確な差 | Ch.2 で可視化する |
# | フィルタリング | 2 変数の組み合わせで品種を特定できる | Ch.3 で機械学習で検証する |
#
# 「数値で気づいたこと」を Ch.2 でグラフにして、Ch.3 でモデルで証明します。
